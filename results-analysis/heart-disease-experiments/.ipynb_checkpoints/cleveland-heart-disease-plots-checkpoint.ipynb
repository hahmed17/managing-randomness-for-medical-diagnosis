# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# # Gaussian NB on Cleveland Heart Disease

# %%
data1 = np.loadtxt("results/gaussian-nb-cleveland-heart.txt", dtype=float)
data1_size = np.size(data1)

# Plot model performance
x_axis = [i for i in range(data1_size)]  # set x-axis to array indices
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x_axis, data1, s=5)
plt.xlabel("Model")
plt.ylabel("Final accuracy")
plt.ylim([0,1])
plt.yticks(np.arange(0, 1, .1))
plt.title("Gaussian Naive Bayes performance on Cleveland Heart Disease data")
plt.savefig("gaussian-nb-cleveland.png", bbox_inches='tight')
plt.show()

# %%
plt.close()

# %%
max_accuracy = np.max(data1)
min_accuracy = np.min(data1)
print ("Max: ", max_accuracy)
print ("Min: ", min_accuracy)
print("Range:", max_accuracy - min_accuracy)
print("Mean: ", np.mean(data1))
print("Std: ", np.std(data1))
# Out:
# Max:  0.7213114754098361
# Min:  0.32786885245901637
# Range: 0.3934426229508197
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-428edb99ac24> in <module>
#       4 print ("Min: ", min_accuracy)
#       5 print("Range:", max_accuracy - min_accuracy)
# ----> 6 prit("Mean: ", np.mean(data1))
#       7 print("Std: ", np.std(data1))
#
# NameError: name 'prit' is not defined

# %% [markdown]
# # Bernoulli NB on Cleveland Heart Disease

# %%
data2 = np.loadtxt("results/bernoulli-nb-cleveland-heart.txt", dtype=float)
data2_size = np.size(data2)

# Plot model performance
x_axis = [i for i in range(data2_size)]  # set x-axis to array indices
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x_axis, data2, s=5)
plt.xlabel("Model")
plt.ylabel("Final accuracy")
plt.ylim([0,1])
plt.yticks(np.arange(0, 1, .1))
plt.title("Bernoulli Naive Bayes performance on Cleveland Heart Disease data")
plt.savefig("bernoulli-nb-cleveland.png", bbox_inches='tight')
plt.show()

# %%
max_accuracy = np.max(data2)
min_accuracy = np.min(data2)
print ("Max: ", max_accuracy)
print ("Min: ", min_accuracy)
print("Range:", max_accuracy - min_accuracy)
print("Mean: ", np.mean(data2))
print("Std: ", np.std(data2))
# Out:
# Max:  0.7049180327868853
# Min:  0.39344262295081966
# Range: 0.3114754098360656
# Std:  0.06174802939884985

# %% [markdown]
# # Random Forest on Cleveland Heart Disease

# %%
data3 = np.loadtxt("results/rf-cleveland-heart.txt", dtype=float)
data3_size = np.size(data3)

# Plot model performance
x_axis = [i for i in range(data3_size)]  # set x-axis to array indices
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x_axis, data3, s=5)
plt.xlabel("Model")
plt.ylabel("Final accuracy")
plt.ylim([0,1])
plt.yticks(np.arange(0, 1, .1))
plt.title("Random Forest Classifier performance on Cleveland Heart Disease data")
plt.savefig("random-forest-cleveland.png", bbox_inches='tight')
plt.show()

# %%
max_accuracy = np.max(data3)
min_accuracy = np.min(data3)
print ("Max: ", max_accuracy)
print ("Min: ", min_accuracy)
print("Range:", max_accuracy - min_accuracy)
print("Mean: ", np.mean(data3))
print("Std: ", np.std(data3))
# Out:
# Max:  0.7049180327868853
# Min:  0.45901639344262296
# Range: 0.2459016393442623
# Std:  0.05331549800322006
