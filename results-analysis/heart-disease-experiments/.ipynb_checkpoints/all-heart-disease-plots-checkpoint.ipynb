# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# # Gaussian NB on All Heart Disease data

# %%
data1 = np.loadtxt("results/gaussian-nb-heart-disease.txt", dtype=float)
data1_size = np.size(data1)

# Plot model performance
x_axis = [i for i in range(data1_size)]  # set x-axis to array indices
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x_axis, data1, s=5)
plt.xlabel("Model")
plt.ylabel("Final accuracy")
plt.ylim([0,1])
plt.yticks(np.arange(0, 1, .1))
plt.title("Gaussian Naive Bayes performance on compiled Heart Disease data")
plt.savefig("gaussian-nb-heart-disease.png", bbox_inches='tight')
plt.show()

# %%
plt.close()

# %%
max_accuracy = np.max(data1)
min_accuracy = np.min(data1)
print ("Max: ", max_accuracy)
print ("Min: ", min_accuracy)
print("Range:", max_accuracy - min_accuracy)
print("Std: ", np.std(data1))
# Out:
# Max:  0.5543478260869565
# Min:  0.34782608695652173
# Range: 0.2065217391304348
# Std:  0.03714541718649035

# %% [markdown]
# # Bernoulli NB on All Heart Disease

# %%
data2 = np.loadtxt("results/bernoulli-nb-heart-disease.txt", dtype=float)
data2_size = np.size(data2)

# Plot model performance
x_axis = [i for i in range(data2_size)]  # set x-axis to array indices
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x_axis, data2, s=5)
plt.xlabel("Model")
plt.ylabel("Final accuracy")
plt.ylim([0,1])
plt.yticks(np.arange(0, 1, .1))
plt.title("Bernoulli Naive Bayes performance on compiled Heart Disease data")
plt.savefig("bernoulli-nb-heart-disease.png", bbox_inches='tight')
plt.show()

# %%
max_accuracy = np.max(data2)
min_accuracy = np.min(data2)
print ("Max: ", max_accuracy)
print ("Min: ", min_accuracy)
print("Range: ", max_accuracy - min_accuracy)
print("Std: ", np.std(data2))
# Out:
# Max:  0.5869565217391305
# Min:  0.41304347826086957
# Range:  0.17391304347826092
# Std:  0.034710352938773406

# %% [markdown]
# # Random Forest on All Heart Disease

# %%
data3 = np.loadtxt("results/rf-heart-disease.txt", dtype=float)
data3_size = np.size(data3)

# Plot model performance
x_axis = [i for i in range(data3_size)]  # set x-axis to array indices
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x_axis, data3, s=5)
plt.xlabel("Model")
plt.ylabel("Final accuracy")
plt.ylim([0,1])
plt.yticks(np.arange(0, 1, .1))
plt.title("Random Forest Classifier performance on compiled Heart Disease data")
plt.savefig("random-forest-heart-disease.png", bbox_inches='tight')
plt.show()

# %%
max_accuracy = np.max(data3)
min_accuracy = np.min(data3)
print ("Max: ", max_accuracy)
print ("Min: ", min_accuracy)
print("Range: ", max_accuracy - min_accuracy)
print("Std: ", np.std(data3))
# Out:
# Max:  0.6032608695652174
# Min:  0.42934782608695654
# Range:  0.17391304347826086
# Std:  0.03714541718649035
