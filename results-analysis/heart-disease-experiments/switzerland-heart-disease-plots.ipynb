# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# # Gaussian NB on Switzerland Heart Disease

# %%
data1 = np.loadtxt("results\gaussian-nb-switzerland-heart.txt", dtype=float)
data1_size = np.size(data1)

# Plot model performance
x_axis = [i for i in range(data1_size)]  # set x-axis to array indices
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x_axis, data1, s=5)
plt.xlabel("Model")
plt.ylabel("Final accuracy")
plt.ylim([0,1])
plt.yticks(np.arange(0, 1, .1))
plt.title("Gaussian Naive Bayes performance on Switzerland Heart Disease data")
plt.savefig("gaussian-nb-switzerland.png", bbox_inches='tight')
plt.show()

# %%
plt.close()

# %%
max_accuracy = np.max(data1)
min_accuracy = np.min(data1)
print ("Max: ", max_accuracy)
print ("Min: ", min_accuracy)
print("Range:", max_accuracy - min_accuracy)
print("Mean: ", np.mean(data1))
print("Median: ", np.median(data1))
print("Std: ", np.std(data1))
# Out:
# Max:  0.36
# Min:  0.0
# Range: 0.36
# Mean:  0.1708
# Median:  0.16
# Std:  0.07458793468115336

# %% [markdown]
# # Bernoulli NB on Switzerland Heart Disease

# %%
data2 = np.loadtxt("results/bernoulli-nb-switzerland-heart.txt", dtype=float)
data2_size = np.size(data2)

# Plot model performance
x_axis = [i for i in range(data2_size)]  # set x-axis to array indices
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x_axis, data2, s=5)
plt.xlabel("Model")
plt.ylabel("Final accuracy")
plt.ylim([0,1])
plt.yticks(np.arange(0, 1, .1))
plt.title("Bernoulli Naive Bayes performance on Switzerland Heart Disease data")
plt.savefig("bernoulli-nb-switzerland.png", bbox_inches='tight')
plt.show()

# %%
max_accuracy = np.max(data2)
min_accuracy = np.min(data2)
print ("Max: ", max_accuracy)
print ("Min: ", min_accuracy)
print("Range:", max_accuracy - min_accuracy)
print("Mean: ", np.mean(data2))
print("Median: ", np.median(data2))
print("Std: ", np.std(data2))
# Out:
# Max:  0.56
# Min:  0.2
# Range: 0.36000000000000004
# Mean:  0.3644
# Median:  0.36
# Std:  0.07395025354926107

# %% [markdown]
# # Random Forest on Switzerland Heart Disease

# %%
data3 = np.loadtxt("results/rf-switzerland-heart.txt", dtype=float)
data3_size = np.size(data3)

# Plot model performance
x_axis = [i for i in range(data3_size)]  # set x-axis to array indices
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x_axis, data3, s=5)
plt.xlabel("Model")
plt.ylabel("Final accuracy")
plt.ylim([0,1])
plt.yticks(np.arange(0, 1, .1))
plt.title("Random Forest Classifier performance on Switzerland Heart Disease data")
plt.savefig("random-forest-switzerland.png", bbox_inches='tight')
plt.show()

# %%
max_accuracy = np.max(data3)
min_accuracy = np.min(data3)
print ("Max: ", max_accuracy)
print ("Min: ", min_accuracy)
print("Range:", max_accuracy - min_accuracy)
print("Mean: ", np.mean(data3))
print("Median: ", np.median(data3))
print("Std: ", np.std(data3))
# Out:
# Max:  0.6
# Min:  0.16
# Range: 0.43999999999999995
# Mean:  0.3868
# Median:  0.4
# Std:  0.08998755469507991
