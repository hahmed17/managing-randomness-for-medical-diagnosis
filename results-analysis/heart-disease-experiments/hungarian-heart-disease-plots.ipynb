# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# # Gaussian NB on Hungarian Heart Disease

# %%
data1 = np.loadtxt("results/gaussian-nb-hungarian-heart.txt", dtype=float)
data1_size = np.size(data1)

# Plot model performance
x_axis = [i for i in range(data1_size)]  # set x-axis to array indices
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x_axis, data1, s=5)
plt.xlabel("Model")
plt.ylabel("Final accuracy")
plt.ylim([0,1])
plt.yticks(np.arange(0, 1, .1))
plt.title("Gaussian Naive Bayes performance on Hungary Heart Disease data")
plt.savefig("gaussian-nb-hungary.png", bbox_inches='tight')
plt.show()

# %%
plt.close()

# %%
max_accuracy = np.max(data1)
min_accuracy = np.min(data1)
print ("Max: ", max_accuracy)
print ("Min: ", min_accuracy)
print("Range:", max_accuracy - min_accuracy)
print("Mean: ", np.mean(data1))
print("Std: ", np.std(data1))
# Out:
# Max:  0.6101694915254238
# Min:  0.06779661016949153
# Range: 0.5423728813559322
# Mean:  0.31000000000000005
# Std:  0.11605640586431695

# %% [markdown]
# # Bernoulli NB on Hungarian Heart Disease

# %%
data2 = np.loadtxt("results/bernoulli-nb-hungarian-heart.txt", dtype=float)
data2_size = np.size(data2)

# Plot model performance
x_axis = [i for i in range(data2_size)]  # set x-axis to array indices
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x_axis, data2, s=5)
plt.xlabel("Model")
plt.ylabel("Final accuracy")
plt.ylim([0,1])
plt.yticks(np.arange(0, 1, .1))
plt.title("Bernoulli Naive Bayes performance on Hungary Heart Disease data")
plt.savefig("bernoulli-nb-hungary.png", bbox_inches='tight')
plt.show()

# %%
max_accuracy = np.max(data2)
min_accuracy = np.min(data2)
print ("Max: ", max_accuracy)
print ("Min: ", min_accuracy)
print("Range:", max_accuracy - min_accuracy)
print("Mean: ", np.mean(data2))
print("Std: ", np.std(data2))
# Out:
# Max:  0.7796610169491526
# Min:  0.5254237288135594
# Range: 0.2542372881355932
# Mean:  0.6274576271186441
# Std:  0.05229465937381435

# %% [markdown]
# # Random Forest on Hungarian Heart Disease

# %%
data3 = np.loadtxt("results/rf-hungarian-heart.txt", dtype=float)
data3_size = np.size(data3)

# Plot model performance
x_axis = [i for i in range(data3_size)]  # set x-axis to array indices
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x_axis, data3, s=5)
plt.xlabel("Model")
plt.ylabel("Final accuracy")
plt.ylim([0,1])
plt.yticks(np.arange(0, 1, .1))
plt.title("Random Forest Classifier performance on Hungary Heart Disease data")
plt.savefig("random-forest-hungary.png", bbox_inches='tight')
plt.show()

# %%
max_accuracy = np.max(data3)
min_accuracy = np.min(data3)
print ("Max: ", max_accuracy)
print ("Min: ", min_accuracy)
print("Range:", max_accuracy - min_accuracy)
print("Mean: ", np.mean(data3))
print("Std: ", np.std(data3))
# Out:
# Max:  0.7966101694915254
# Min:  0.559322033898305
# Range: 0.23728813559322037
# Mean:  0.6616949152542374
# Std:  0.05256533123349881
